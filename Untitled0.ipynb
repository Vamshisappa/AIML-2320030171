# %%
print['vamshi krishna patel']

# %%
print["vamshi krishna patel"]

# %%
x="vamshi"
x='vamshi'
x=18
print(x)

# %%
x=str(3)
y=int(3)
z=float(3)
print (x)
print (y)
print (z)

# %%
1+9+1+1+2+0+0+4
# Out:
# 18
